# %%
import pandas as pd

# %%
data =pd.read_csv(r"C:\Users\sanba\Desktop\Me\cmc\PROJET\PFE\file_path .csv")
# Out:
# C:\Users\sanba\AppData\Local\Temp\ipykernel_11812\2719323959.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data =pd.read_csv(r"C:\Users\sanba\Desktop\Me\cmc\PROJET\PFE\file_path .csv")

# %%
data
# Out:
#              DATE VISITE   MARQUE        TYPE MIS EN CIRCULATION   POIDS  \
# 0       04/01/2024 08:23    DACIA      HSDAW5         16/12/2011  1600.0
# 1       04/01/2024 12:45  RENAULT   VF1KCO7BF         02/01/2008  1571.0
# 2       04/01/2024 09:28    DACIA      JSDBW4         19/07/2022  1600.0
# 3       04/01/2024 13:12  PEUGEOT         205         31/12/1984  1600.0
# 4       04/01/2024 13:00     FIAT  312AXA1AXX         09/11/2009  1600.0
# ...                  ...      ...         ...                ...     ...
# 499940  31/12/2024 13:01  RENAULT      FLBVB6         21/09/2010  2385.0
# 499941  31/12/2024 13:18  PEUGEOT      LHAHWW         25/04/2016  1455.0
# 499942  31/12/2024 13:40  PEUGEOT   VF3DD9HJC         07/12/2015  1135.0
# 499943  31/12/2024 13:21  RENAULT      C57205         30/10/1991   925.0
# 499944  12/12/2024 14:15     SEAT         5FP         16/07/2020  1752.0
#
#         FORCE_AV_G  FORCE_AV_D  FORCE_AR_G FORCE_AR_D  EFFICACITE
# ...

# %%
data["DATE VISITE"] = pd.to_datetime(data["DATE VISITE"], format="%d/%m/%Y %H:%M", dayfirst=True).dt.date

# %%
data["MIS EN CIRCULATION"] = pd.to_datetime(data["MIS EN CIRCULATION"], format='mixed', dayfirst=True, errors='coerce').dt.date

# %%
data["DATE VISITE"] = pd.to_datetime(data["DATE VISITE"]).dt.date
data
# Out:
#        DATE VISITE   MARQUE        TYPE MIS EN CIRCULATION   POIDS  \
# 0       2024-01-04    DACIA      HSDAW5         2011-12-16  1600.0
# 1       2024-01-04  RENAULT   VF1KCO7BF         2008-01-02  1571.0
# 2       2024-01-04    DACIA      JSDBW4         2022-07-19  1600.0
# 3       2024-01-04  PEUGEOT         205         1984-12-31  1600.0
# 4       2024-01-04     FIAT  312AXA1AXX         2009-11-09  1600.0
# ...            ...      ...         ...                ...     ...
# 499940  2024-12-31  RENAULT      FLBVB6         2010-09-21  2385.0
# 499941  2024-12-31  PEUGEOT      LHAHWW         2016-04-25  1455.0
# 499942  2024-12-31  PEUGEOT   VF3DD9HJC         2015-12-07  1135.0
# 499943  2024-12-31  RENAULT      C57205         1991-10-30   925.0
# 499944  2024-12-12     SEAT         5FP         2020-07-16  1752.0
#
#         FORCE_AV_G  FORCE_AV_D  FORCE_AR_G FORCE_AR_D  EFFICACITE
# 0            238.0       261.0       201.0        210        57.0
# ...

# %%
cols_to_convert = ["FORCE_AV_G", "FORCE_AV_D", "FORCE_AR_G", "FORCE_AR_D", "POIDS","EFFICACITE"]
for col in cols_to_convert:
    data[col] = pd.to_numeric(data[col], errors="coerce")


data[cols_to_convert] = data[cols_to_convert].astype("Int64")

# %%
data
# Out:
#        DATE VISITE   MARQUE        TYPE MIS EN CIRCULATION  POIDS  FORCE_AV_G  \
# 0       2024-01-04    DACIA      HSDAW5         2011-12-16   1600         238
# 1       2024-01-04  RENAULT   VF1KCO7BF         2008-01-02   1571         249
# 2       2024-01-04    DACIA      JSDBW4         2022-07-19   1600         238
# 3       2024-01-04  PEUGEOT         205         1984-12-31   1600         238
# 4       2024-01-04     FIAT  312AXA1AXX         2009-11-09   1600         238
# ...            ...      ...         ...                ...    ...         ...
# 499940  2024-12-31  RENAULT      FLBVB6         2010-09-21   2385         405
# 499941  2024-12-31  PEUGEOT      LHAHWW         2016-04-25   1455         298
# 499942  2024-12-31  PEUGEOT   VF3DD9HJC         2015-12-07   1135         228
# 499943  2024-12-31  RENAULT      C57205         1991-10-30    925         150
# 499944  2024-12-12     SEAT         5FP         2020-07-16   1752         274
#
# ...

# %%
data.to_csv("datafinal.csv", index=False)

# %%
df_true = data[["MARQUE","POIDS"]]
df_true
# Out:
#          MARQUE  POIDS
# 0         DACIA   1600
# 1       RENAULT   1571
# 2         DACIA   1600
# 3       PEUGEOT   1600
# 4          FIAT   1600
# ...         ...    ...
# 499940  RENAULT   2385
# 499941  PEUGEOT   1455
# 499942  PEUGEOT   1135
# 499943  RENAULT    925
# 499944     SEAT   1752
#
# [499945 rows x 2 columns]

# %%
df_poids = pd.read_csv(r"C:\Users\sanba\Desktop\Me\cmc\PROJET\PFE\MISE EN CIRCULATION\DriveArabia_All_uae.csv\DriveArabia_All_uae.csv")

# %%
df_poids
# Out:
#                                                    Link  \
# 0     https://www.drivearabia.com/carprices/uae/merc...
# 1     https://www.drivearabia.com/carprices/uae/jeep...
# 2     https://www.drivearabia.com/carprices/uae/niss...
# 3     https://www.drivearabia.com/carprices/uae/lamb...
# 4     https://www.drivearabia.com/carprices/uae/dodg...
# ...                                                 ...
# 7643  https://www.drivearabia.com/carprices/uae/cadi...
# 7644  https://www.drivearabia.com/carprices/uae/chry...
# 7645  https://www.drivearabia.com/carprices/uae/mahi...
# 7646  https://www.drivearabia.com/carprices/uae/jagu...
# 7647  https://www.drivearabia.com/carprices/uae/suzu...
#
#                               Approx Cost  Origin Country Sale Country  \
# 0                     AED 37,200 - 61,000         Germany          uae
# 1             AED 67,700 - 69,900 (Sport)   United States          uae
# 2         AED 22,700 - 24,700 (Panel Van)           Japan          uae
# ...

# %%
df_poids = df_poids[["Manufacturer","Weight"]]

# %%
df_poids[['Weight_Min', 'Weight_Max']] = df_poids['Weight'].str.split(' - ', expand=True)

# Convert the new columns to numeric types (integers or floats)
df_poids['Weight_Min'] = pd.to_numeric(df_poids['Weight_Min'], errors='coerce')
df_poids['Weight_Max'] = pd.to_numeric(df_poids['Weight_Max'], errors='coerce')
# Out:
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\2658518536.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids[['Weight_Min', 'Weight_Max']] = df_poids['Weight'].str.split(' - ', expand=True)
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\2658518536.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids[['Weight_Min', 'Weight_Max']] = df_poids['Weight'].str.split(' - ', expand=True)
# ...

# %%
df_poids
# Out:
#        Manufacturer               Weight  Weight_Min  Weight_Max
# 0     Mercedes-Benz  1730 - \r\n    1920      1730.0      1920.0
# 1              Jeep                 1973      1973.0         NaN
# 2            Nissan          1675 - 1810      1675.0      1810.0
# 3       Lamborghini                 1422      1422.0         NaN
# 4             Dodge          1797 - 1984      1797.0      1984.0
# ...             ...                  ...         ...         ...
# 7643       Cadillac          1750 - 1948      1750.0      1948.0
# 7644       Chrysler          1398 - 1596      1398.0      1596.0
# 7645       Mahindra          1760 - 2060      1760.0      2060.0
# 7646         Jaguar          1693 - 1990      1693.0      1990.0
# 7647         Suzuki                 1140      1140.0         NaN
#
# [7648 rows x 4 columns]

# %%
df_poids = df_poids[["Manufacturer","Weight_Min","Weight_Max"]]

# %%
df_poids
# Out:
#        Manufacturer  Weight_Min  Weight_Max
# 0     Mercedes-Benz      1730.0      1920.0
# 1              Jeep      1973.0         NaN
# 2            Nissan      1675.0      1810.0
# 3       Lamborghini      1422.0         NaN
# 4             Dodge      1797.0      1984.0
# ...             ...         ...         ...
# 7643       Cadillac      1750.0      1948.0
# 7644       Chrysler      1398.0      1596.0
# 7645       Mahindra      1760.0      2060.0
# 7646         Jaguar      1693.0      1990.0
# 7647         Suzuki      1140.0         NaN
#
# [7648 rows x 3 columns]

# %%
cols_to_convert = ["Weight_Min","Weight_Max"]
for col in cols_to_convert:
    df_poids[col] = pd.to_numeric(df_poids[col], errors="coerce")


df_poids[cols_to_convert] = df_poids[cols_to_convert].astype("Int64")
# Out:
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\4066661125.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids[col] = pd.to_numeric(df_poids[col], errors="coerce")
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\4066661125.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids[cols_to_convert] = df_poids[cols_to_convert].astype("Int64")

# %%
df_poids
# Out:
#        Manufacturer  Weight_Min  Weight_Max
# 0     Mercedes-Benz        1730        1920
# 1              Jeep        1973        <NA>
# 2            Nissan        1675        1810
# 3       Lamborghini        1422        <NA>
# 4             Dodge        1797        1984
# ...             ...         ...         ...
# 7643       Cadillac        1750        1948
# 7644       Chrysler        1398        1596
# 7645       Mahindra        1760        2060
# 7646         Jaguar        1693        1990
# 7647         Suzuki        1140        <NA>
#
# [7648 rows x 3 columns]

# %%
df_poids["Manufacturer"].unique()
# Out:
# array(['Mercedes-Benz', 'Jeep', 'Nissan', 'Lamborghini', 'Dodge', 'BMW',
#        'Ssangyong', 'Toyota', 'Mini', 'Audi', 'Honda', 'Ford',
#        'Mitsubishi', 'Mazda', 'Lexus', 'Infiniti', 'Peugeot', 'Opel',
#        'Kia', 'Ferrari', 'Subaru', 'Volkswagen', 'Dongfeng', 'Bentley',
#        'Citroen', 'Hyundai', 'Cadillac', 'Mercury', 'Maxus', 'Chevrolet',
#        'Volvo', 'GMC', 'Dorcen', 'Renault', 'Maserati', 'Changan',
#        'Lotus', 'Suzuki', 'Jaguar', 'Saab', 'Chery', 'ZNA', 'Chrysler',
#        'Seat', 'JAC', 'Porsche', 'Ram', 'Zotye', 'Isuzu', 'McLaren',
#        'Skoda', 'Geely', 'Daihatsu', 'BYD', 'Genesis', 'Acura', 'GAC',
#        'MG', 'Luxgen', 'Bugatti', 'Lincoln', 'Fiat', 'BAIC', 'Mahindra',
#        'KTM', 'Hummer', 'Brilliance', 'Borgward', 'Proton', 'Pagani',
#        'Hongqi', 'Abarth', 'Soueast', 'Foton', 'PGO', 'Tesla', 'Tata',
#        'Caterham', 'Maybach', 'Fisker', 'CMC', 'Koenigsegg', 'Spyker',
# ...

# %%
df_poids = df_poids.dropna(subset=["Manufacturer", "Weight_Min", "Weight_Max"])
df_poids
# Out:
#        Manufacturer  Weight_Min  Weight_Max
# 0     Mercedes-Benz        1730        1920
# 2            Nissan        1675        1810
# 4             Dodge        1797        1984
# 5               BMW        1700        1825
# 6         Ssangyong        1971        2046
# ...             ...         ...         ...
# 7642            BMW        1825        1940
# 7643       Cadillac        1750        1948
# 7644       Chrysler        1398        1596
# 7645       Mahindra        1760        2060
# 7646         Jaguar        1693        1990
#
# [4991 rows x 3 columns]

# %%
df_poids["Weight_Min"] = pd.to_numeric(df_poids["Weight_Min"])
df_poids["Weight_Max"] = pd.to_numeric(df_poids["Weight_Max"])
# Out:
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\1953578778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids["Weight_Min"] = pd.to_numeric(df_poids["Weight_Min"])
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\1953578778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids["Weight_Max"] = pd.to_numeric(df_poids["Weight_Max"])

# %%
df_poids["Weight_Avg"] = (df_poids["Weight_Min"] + df_poids["Weight_Max"]) / 2
df_poids = df_poids[["Manufacturer", "Weight_Avg"]]
# Out:
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\2313895709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids["Weight_Avg"] = (df_poids["Weight_Min"] + df_poids["Weight_Max"]) / 2

# %%
df_poids
# Out:
#        Manufacturer  Weight_Avg
# 0     Mercedes-Benz      1825.0
# 2            Nissan      1742.5
# 4             Dodge      1890.5
# 5               BMW      1762.5
# 6         Ssangyong      2008.5
# ...             ...         ...
# 7642            BMW      1882.5
# 7643       Cadillac      1849.0
# 7644       Chrysler      1497.0
# 7645       Mahindra      1910.0
# 7646         Jaguar      1841.5
#
# [4991 rows x 2 columns]

# %%
df_poids["Manufacturer"] = df_poids["Manufacturer"].str.upper()
# Out:
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\2408358385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids["Manufacturer"] = df_poids["Manufacturer"].str.upper()

# %%
df_poids
# Out:
#        Manufacturer  Weight_Avg
# 0     MERCEDES-BENZ      1825.0
# 2            NISSAN      1742.5
# 4             DODGE      1890.5
# 5               BMW      1762.5
# 6         SSANGYONG      2008.5
# ...             ...         ...
# 7642            BMW      1882.5
# 7643       CADILLAC      1849.0
# 7644       CHRYSLER      1497.0
# 7645       MAHINDRA      1910.0
# 7646         JAGUAR      1841.5
#
# [4991 rows x 2 columns]

# %%
df_poids["Weight_Avg"] = df_poids["Weight_Avg"].astype(int)
# Out:
# C:\Users\sanba\AppData\Local\Temp\ipykernel_17176\1991465670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poids["Weight_Avg"] = df_poids["Weight_Avg"].astype(int)

# %%
df_poids
# Out:
#        Manufacturer  Weight_Avg
# 0     MERCEDES-BENZ        1825
# 2            NISSAN        1742
# 4             DODGE        1890
# 5               BMW        1762
# 6         SSANGYONG        2008
# ...             ...         ...
# 7642            BMW        1882
# 7643       CADILLAC        1849
# 7644       CHRYSLER        1497
# 7645       MAHINDRA        1910
# 7646         JAGUAR        1841
#
# [4991 rows x 2 columns]

# %%
df_true
# Out:
#          MARQUE  POIDS
# 0         DACIA   1600
# 1       RENAULT   1571
# 2         DACIA   1600
# 3       PEUGEOT   1600
# 4          FIAT   1600
# ...         ...    ...
# 499940  RENAULT   2385
# 499941  PEUGEOT   1455
# 499942  PEUGEOT   1135
# 499943  RENAULT    925
# 499944     SEAT   1752
#
# [499945 rows x 2 columns]

# %%
df_true_renamed = df_true.rename(columns={"MARQUE": "Manufacturer", "POIDS": "Weight_Avg"})

# %%
df_merged = pd.concat([df_poids, df_true_renamed], ignore_index=True)

# %%
df_merged
# Out:
#          Manufacturer  Weight_Avg
# 0       MERCEDES-BENZ        1825
# 1              NISSAN        1742
# 2               DODGE        1890
# 3                 BMW        1762
# 4           SSANGYONG        2008
# ...               ...         ...
# 504931        RENAULT        2385
# 504932        PEUGEOT        1455
# 504933        PEUGEOT        1135
# 504934        RENAULT         925
# 504935           SEAT        1752
#
# [504936 rows x 2 columns]

# %%
df_merged.to_csv("merged_data.csv", index=False)
